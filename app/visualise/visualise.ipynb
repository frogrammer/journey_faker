# %%
# !pip install -r ../../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: aiohttp in /home/moss/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: contextily in /home/moss/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: faker in /home/moss/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 3)) (13.16.0)
# Requirement already satisfied: faker-wifi-essid in /home/moss/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: geopandas in /home/moss/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 5)) (0.11.1)
# Requirement already satisfied: haversine in /home/moss/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 6)) (2.7.0)
# Requirement already satisfied: matplotlib in /home/moss/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 7)) (3.5.3)
# Requirement already satisfied: python-dotenv in /home/moss/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 8)) (0.21.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/moss/.local/lib/python3.10/site-packages (from aiohttp->-r ../../requirements.txt (line 1)) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/moss/.local/lib/python3.10/site-packages (from aiohttp->-r ../../requirements.txt (line 1)) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/moss/.local/lib/python3.10/site-packages (from aiohttp->-r ../../requirements.txt (line 1)) (1.8.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/moss/.local/lib/python3.10/site-packages (from aiohttp->-r ../../requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/moss/.local/lib/python3.10/site-packages (from aiohttp->-r ../../requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/moss/.local/lib/python3.10/site-packages (from aiohttp->-r ../../requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/moss/.local/lib/python3.10/site-packages (from aiohttp->-r ../../requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: rasterio in /home/moss/.local/lib/python3.10/site-packages (from contextily->-r ../../requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: xyzservices in /home/moss/.local/lib/python3.10/site-packages (from contextily->-r ../../requirements.txt (line 2)) (2022.6.0)
# Requirement already satisfied: joblib in /home/moss/.local/lib/python3.10/site-packages (from contextily->-r ../../requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: geopy in /home/moss/.local/lib/python3.10/site-packages (from contextily->-r ../../requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: pillow in /usr/lib/python3/dist-packages (from contextily->-r ../../requirements.txt (line 2)) (9.0.1)
# Requirement already satisfied: mercantile in /home/moss/.local/lib/python3.10/site-packages (from contextily->-r ../../requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from contextily->-r ../../requirements.txt (line 2)) (2.25.1)
# Requirement already satisfied: python-dateutil>=2.4 in /home/moss/.local/lib/python3.10/site-packages (from faker->-r ../../requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: packaging in /home/moss/.local/lib/python3.10/site-packages (from geopandas->-r ../../requirements.txt (line 5)) (21.3)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /home/moss/.local/lib/python3.10/site-packages (from geopandas->-r ../../requirements.txt (line 5)) (3.4.0)
# Requirement already satisfied: pandas>=1.0.0 in /home/moss/.local/lib/python3.10/site-packages (from geopandas->-r ../../requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: shapely<2,>=1.7 in /home/moss/.local/lib/python3.10/site-packages (from geopandas->-r ../../requirements.txt (line 5)) (1.8.4)
# Requirement already satisfied: fiona>=1.8 in /home/moss/.local/lib/python3.10/site-packages (from geopandas->-r ../../requirements.txt (line 5)) (1.8.21)
# Requirement already satisfied: fonttools>=4.22.0 in /home/moss/.local/lib/python3.10/site-packages (from matplotlib->-r ../../requirements.txt (line 7)) (4.37.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib->-r ../../requirements.txt (line 7)) (2.4.7)
# Requirement already satisfied: numpy>=1.17 in /home/moss/.local/lib/python3.10/site-packages (from matplotlib->-r ../../requirements.txt (line 7)) (1.23.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/moss/.local/lib/python3.10/site-packages (from matplotlib->-r ../../requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/moss/.local/lib/python3.10/site-packages (from matplotlib->-r ../../requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: six>=1.7 in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas->-r ../../requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: cligj>=0.5 in /home/moss/.local/lib/python3.10/site-packages (from fiona>=1.8->geopandas->-r ../../requirements.txt (line 5)) (0.7.2)
# Requirement already satisfied: munch in /home/moss/.local/lib/python3.10/site-packages (from fiona>=1.8->geopandas->-r ../../requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: click>=4.0 in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas->-r ../../requirements.txt (line 5)) (8.0.3)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas->-r ../../requirements.txt (line 5)) (59.6.0)
# Requirement already satisfied: click-plugins>=1.0 in /home/moss/.local/lib/python3.10/site-packages (from fiona>=1.8->geopandas->-r ../../requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas->-r ../../requirements.txt (line 5)) (2020.6.20)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.0.0->geopandas->-r ../../requirements.txt (line 5)) (2022.1)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.0->aiohttp->-r ../../requirements.txt (line 1)) (3.3)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/moss/.local/lib/python3.10/site-packages (from geopy->contextily->-r ../../requirements.txt (line 2)) (1.52)
# Requirement already satisfied: affine in /home/moss/.local/lib/python3.10/site-packages (from rasterio->contextily->-r ../../requirements.txt (line 2)) (2.3.1)
# Requirement already satisfied: snuggs>=1.4.1 in /home/moss/.local/lib/python3.10/site-packages (from rasterio->contextily->-r ../../requirements.txt (line 2)) (1.4.7)

# %%
import contextily as cx
import geopandas as gpd
import matplotlib
import pandas as pd

# %% [markdown]
# Story

# %%
telemetry_df = pd.read_csv('../../out/telemetry.csv')
telemetry_gdf = gpd.GeoDataFrame(telemetry_df, geometry=gpd.GeoSeries.from_xy(telemetry_df['lng'], telemetry_df['lat'], crs=4326))
ax = telemetry_gdf.plot(markersize=1, c=telemetry_gdf['colour'])
cx.add_basemap(ax, source=cx.providers.AzureMaps.MicrosoftBaseRoad(subscriptionKey='vLBtoar7V4TCHVp--WKPv5D5JhPJoNTJmXGM_LjB40A'), crs=4326)

# %%
story_df = pd.read_csv('../../out/telemetry.csv')
story_gdf = gpd.GeoDataFrame(story_df, geometry=gpd.GeoSeries.from_xy(story_df['lng'], story_df['lat'], crs=4326))
ax = story_gdf.plot(markersize=1, c=story_gdf['colour'])
cx.add_basemap(ax, source=cx.providers.AzureMaps.MicrosoftBaseRoad(subscriptionKey='vLBtoar7V4TCHVp--WKPv5D5JhPJoNTJmXGM_LjB40A'), crs=4326)
